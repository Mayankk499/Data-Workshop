# %%
print('Hello Data')
# Out:
# Hello Data

# %%
10
# Out:
# 10

# %%
10+20
# Out:
# 30

# %%
sales = [125, 205, 183, 312]

# %%
type(sales)
# Out:
# list

# %%
cities = ['UTRPRDSH', 'UTRKND', 'DEL', 'HRYN']

# %%
type(cities)
# Out:
# list

# %%
score = [75, 80, 90, None, 'Absent', 65]

# %%
sum(sales)
# Out:
# 825

# %%
type(score)
# Out:
# list

# %%
cities[1:3]
# Out:
# ['UK', 'DL']

# %%
for city in cities:
    print(len(city))
# Out:
# 8
# 6
# 3
# 4
